# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq

# %%
llm=ChatGroq(model="deepseek-r1-distill-llama-70b")
# Out:
# ---------------------------------------------------------------------------
# GroqError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 llm=ChatGroq(model="deepseek-r1-distill-llama-70b")
#
# File d:\AutoAprendizaje\Ingenieria_De_Datos\AI_Trip_Planner\AI_Trip_Planner\env\Lib\site-packages\langchain_core\load\serializable.py:117, in Serializable.__init__(self, *args, **kwargs)
#     115 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     116     """"""  # noqa: D419  # Intentional blank docstring
# --> 117     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File d:\AutoAprendizaje\Ingenieria_De_Datos\AI_Trip_Planner\AI_Trip_Planner\env\Lib\site-packages\langchain_groq\chat_models.py:492, in ChatGroq.validate_environment(self)
#     490 sync_specific: dict[str, Any] = {"http_client": self.http_client}
#     491 if not self.client:
# --> 492     self.client = groq.Groq(
#     493         **client_params, **sync_specific
#     494     ).chat.completions
#     495 if not self.async_client:
#     496     async_specific: dict[str, Any] = {"http_client": self.http_async_client}
#
# File d:\AutoAprendizaje\Ingenieria_De_Datos\AI_Trip_Planner\AI_Trip_Planner\env\Lib\site-packages\groq\_client.py:79, in Groq.__init__(self, api_key, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#      77     api_key = os.environ.get("GROQ_API_KEY")
#      78 if api_key is None:
# ---> 79     raise GroqError(
#      80         "The api_key client option must be set either by passing api_key to the client or by setting the GROQ_API_KEY environment variable"
#      81     )
#      82 self.api_key = api_key
#      84 if base_url is None:
#
# GroqError: The api_key client option must be set either by passing api_key to the client or by setting the GROQ_API_KEY environment variable

# %%
llm.invoke("hi")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 llm.invoke("hi")
#
# NameError: name 'llm' is not defined
